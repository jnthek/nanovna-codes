# %%
from nanovna import NanoVNA
import numpy as np
import matplotlib.pyplot as plt

# %%
nv = NanoVNA()

# %%
filename = "long_cable.txt"
nv.set_sweep(50e6, 200e6)
nv.fetch_frequencies()
freq = nv.frequencies

# %%
s11 = nv.data(0)
plt.plot(freq, np.real(s11))
plt.plot(freq, np.imag(s11))
np.savetxt(filename, np.column_stack([freq, np.real(s11), np.imag(s11)]))

# %%
# pfit = np.polyfit(freq, np.abs(s11), 2)
# s11_poly = np.polyval(pfit,freq)

# %%
# plt.figure()
# plt.plot(freq, np.real(s11))
# plt.plot(freq, s11_poly)

# plt.figure()
# plt.plot(freq, np.abs(s11)-s11_poly)
